# %%
import pandas as pd
import numpy as np

# %%
df_transaction = pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name =1, header=1)
df_customer_list = pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name =2, header=1)
df_cust_demo = pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name =3, header=1)
df_cust_address = pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name =4, header=1)

# %%
pd.set_option('display.max_columns', 100)

# %%
df_cust_demo.set_index('customer_id')
# Out:
#                  first_name  last_name  gender  \
# customer_id
# 1                   Laraine  Medendorp       F
# 2                       Eli    Bockman    Male
# 3                     Arlin     Dearle    Male
# 4                    Talbot        NaN    Male
# 5            Sheila-kathryn     Calton  Female
# ...                     ...        ...     ...
# 3996                Rosalia   Halgarth  Female
# 3997                 Blanch     Nisuis  Female
# 3998                 Sarene    Woolley       U
# 3999              Patrizius        NaN    Male
# 4000                  Kippy    Oldland    Male
#
#              past_3_years_bike_related_purchases        DOB  \
# customer_id
# 1                                             93 1953-10-12
# 2                                             81 1980-12-16
# 3                                             61 1954-01-20
# 4                                             33 1961-10-03
# 5                                             56 1977-05-13
# ...

# %%
df_customer_list.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
df_customer_list.isna().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
df_customer_list['deceased_indicator'].value_counts()
# Out:
# N    1000
# Name: deceased_indicator, dtype: int64

# %%
df_customer_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
# first_name                             1000 non-null object
# last_name                              971 non-null object
# gender                                 1000 non-null object
# past_3_years_bike_related_purchases    1000 non-null int64
# DOB                                    983 non-null datetime64[ns]
# job_title                              894 non-null object
# job_industry_category                  835 non-null object
# wealth_segment                         1000 non-null object
# deceased_indicator                     1000 non-null object
# owns_car                               1000 non-null object
# tenure                                 1000 non-null int64
# address                                1000 non-null object
# postcode                               1000 non-null int64
# state                                  1000 non-null object
# ...

# %%
df_cust_demo.tail()
# Out:
#       customer_id first_name last_name  gender  \
# 3995         3996    Rosalia  Halgarth  Female
# 3996         3997     Blanch    Nisuis  Female
# 3997         3998     Sarene   Woolley       U
# 3998         3999  Patrizius       NaN    Male
# 3999         4000      Kippy   Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB              job_title  \
# 3995                                    8 1975-08-09  VP Product Management
# 3996                                   87 2001-07-13        Statistician II
# 3997                                   60        NaT      Assistant Manager
# 3998                                   11 1973-10-24                    NaN
# 3999                                   76 1991-11-05   Software Engineer IV
#
#      job_industry_category     wealth_segment deceased_indicator  \
# 3995                Health      Mass Customer                  N
# 3996         Manufacturing     High Net Worth                  N
# ...

# %%
df_cust_demo.isna().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
df_cust_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
# customer_id                            4000 non-null int64
# first_name                             4000 non-null object
# last_name                              3875 non-null object
# gender                                 4000 non-null object
# past_3_years_bike_related_purchases    4000 non-null int64
# DOB                                    3913 non-null datetime64[ns]
# job_title                              3494 non-null object
# job_industry_category                  3344 non-null object
# wealth_segment                         4000 non-null object
# deceased_indicator                     4000 non-null object
# default                                3698 non-null object
# owns_car                               4000 non-null object
# tenure                                 3913 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# ...

# %%
filt = df_cust_demo['job_title']=='Business Systems Development Analyst'
df_cust_demo[filt]
# Out:
#       customer_id first_name      last_name  gender  \
# 8               9       Mala           Lind  Female
# 77             78       Arch  Van der Kruis    Male
# 439           440     Sheena       O'Duggan  Female
# 590           591     Sydney       Endacott    Male
# 669           670    Janifer       Pountain  Female
# 745           746       Aldo       Waistall    Male
# 750           751       Amie          Dufty  Female
# 898           899    Teodora        Lawling  Female
# 1001         1002    Pacorro   De Clairmont    Male
# 1003         1004      Colas       Pumfrett    Male
# 1092         1093    Clarita       Penright  Female
# 1136         1137   Jermayne    Hryniewicki    Male
# 1151         1152    Humfrid         Ducket    Male
# 1204         1205     Barton         Baudts    Male
# 1520         1521    Pernell        Duffett    Male
# 1837         1838     Jobina        Dudenie  Female
# 2049         2050       Opal          Costa  Female
# ...

# %%
df_cust_address.isna().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
df_cust_address.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
df_cust_address['state'].value_counts()
# Out:
# NSW                2054
# VIC                 939
# QLD                 838
# New South Wales      86
# Victoria             82
# Name: state, dtype: int64

# %%
print(df_customer_list.shape)
print(df_cust_demo.shape)
print(df_cust_address.shape)
print(df_transaction.shape)
# Out:
# (1000, 23)
# (4000, 13)
# (3999, 6)
# (20000, 13)

# %%
filt = df_cust_demo['last_name'].isna()
df_cust_demo[filt]
# Out:
#       customer_id first_name last_name  gender  \
# 3               4     Talbot       NaN    Male
# 66             67     Vernon       NaN    Male
# 105           106       Glyn       NaN    Male
# 138           139        Gar       NaN    Male
# 196           197       Avis       NaN  Female
# ...           ...        ...       ...     ...
# 3884         3885      Asher       NaN    Male
# 3915         3916     Myrtia       NaN  Female
# 3926         3927     Conway       NaN    Male
# 3961         3962     Benoit       NaN    Male
# 3998         3999  Patrizius       NaN    Male
#
#       past_3_years_bike_related_purchases        DOB  \
# 3                                      33 1961-10-03
# 66                                     67 1960-06-14
# 105                                    54 1966-07-03
# 138                                     1 1964-07-28
# 196                                    32 1977-01-27
# ...                                   ...        ...
# ...

# %%
df_cust_address['address'].value_counts()
# Out:
# 3 Talisman Place           2
# 3 Mariners Cove Terrace    2
# 64 Macpherson Junction     2
# 7202 Prairieview Court     1
# 3 Lyons Road               1
#                           ..
# 638 Thackeray Junction     1
# 352 Forster Place          1
# 04488 Amoth Parkway        1
# 8 Talisman Avenue          1
# 226 Rowland Street         1
# Name: address, Length: 3996, dtype: int64

# %%
df_customer_list['DOB'].value_counts()
# Out:
# 1961-07-31    2
# 1994-04-15    2
# 1987-01-15    2
# 1951-11-28    2
# 1979-07-28    2
#              ..
# 1947-04-21    1
# 1995-10-10    1
# 1964-08-23    1
# 1962-05-12    1
# 1958-04-21    1
# Name: DOB, Length: 958, dtype: int64

# %%
df_cust_demo['DOB'].value_counts()
# Out:
# 1978-01-30    7
# 1977-05-13    4
# 1976-07-16    4
# 1978-08-19    4
# 1976-09-25    4
#              ..
# 1974-06-16    1
# 1969-11-21    1
# 1961-11-24    1
# 1995-05-03    1
# 1972-04-14    1
# Name: DOB, Length: 3448, dtype: int64

# %%
df_customer_list.merge(df_cust_address, how='inner', on='address')
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Vinny    Incogna  Female                                   73
# 1   Aldridge    Poskitt    Male                                   84
# 2    Jenelle  Mc-Kerley  Female                                   40
# 3      Ewell   Paulusch    Male                                   31
# 4   Kariotta      Naper  Female                                    8
# 5     Myrtie    Ostrich  Female                                   70
#
#          DOB           job_title job_industry_category     wealth_segment  \
# 0 1953-02-13                 NaN                Health     High Net Worth
# 1 1982-02-10            VP Sales                   NaN      Mass Customer
# 2 1942-01-23     Data Coordiator    Financial Services      Mass Customer
# 3 1998-01-15          Engineer I         Manufacturing      Mass Customer
# 4 1952-04-07            VP Sales                Health      Mass Customer
# ...

# %%
filt = df_cust_demo['DOB'].isin(['1843-12-21', '2002-03-11'])
df_cust_demo[filt]
# Out:
#     customer_id first_name last_name gender  \
# 33           34   Jephthah  Bachmann      U
# 65           66     Anselm     Gawne   Male
#
#     past_3_years_bike_related_purchases        DOB          job_title  \
# 33                                   59 1843-12-21    Legal Assistant
# 65                                   46 2002-03-11  Account Executive
#
#    job_industry_category     wealth_segment deceased_indicator        default  \
# 33                    IT  Affluent Customer                  N            NaN
# 65           Argiculture     High Net Worth                  N  ï½ï½¨(Â´âï½â©
#
#    owns_car  tenure
# 33       No    20.0
# 65       No     1.0

# %%
df_cust_demo['wealth_segment'].value_counts()
# Out:
# Mass Customer        2000
# High Net Worth       1021
# Affluent Customer     979
# Name: wealth_segment, dtype: int64

# %%
filt = df_cust_address['customer_id']==34
df_cust_address[filt]
# Out:
#     customer_id         address  postcode state    country  property_valuation
# 29           34  833 Luster Way      4005   QLD  Australia                   8

# %%
filt = df_customer_list['postcode']== 4005
df_customer_list[filt]
# Out:
#     first_name last_name gender  past_3_years_bike_related_purchases  \
# 283     Dexter    Shutle   Male                                   81
#
#            DOB                   job_title job_industry_category  \
# 283 1959-01-05  Quality Control Specialist                   NaN
#
#     wealth_segment deceased_indicator owns_car  tenure          address  \
# 283  Mass Customer                  N       No      17  07 Dayton Court
#
#      postcode state    country  property_valuation  Unnamed: 16  Unnamed: 17  \
# 283      4005   QLD  Australia                   7         0.91         0.91
#
#      Unnamed: 18  Unnamed: 19  Unnamed: 20  Rank     Value
# 283       1.1375     0.966875          284   284  1.046875

# %%
filt = df_cust_demo['customer_id']== 4003

# %%
df_cust_demo[filt]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, default, owns_car, tenure]
# Index: []

# %%
df_cust_demo.tail()
# Out:
#       customer_id first_name last_name  gender  \
# 3995         3996    Rosalia  Halgarth  Female
# 3996         3997     Blanch    Nisuis  Female
# 3997         3998     Sarene   Woolley       U
# 3998         3999  Patrizius       NaN    Male
# 3999         4000      Kippy   Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB              job_title  \
# 3995                                    8 1975-08-09  VP Product Management
# 3996                                   87 2001-07-13        Statistician II
# 3997                                   60        NaT      Assistant Manager
# 3998                                   11 1973-10-24                    NaN
# 3999                                   76 1991-11-05   Software Engineer IV
#
#      job_industry_category     wealth_segment deceased_indicator  \
# 3995                Health      Mass Customer                  N
# 3996         Manufacturing     High Net Worth                  N
# ...

# %%
df_transaction.isna().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
df_transaction.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
df_transaction['online_order'].value_counts()
# Out:
# 1.0    9829
# 0.0    9811
# Name: online_order, dtype: int64

# %%
filt = (df_transaction['standard_cost'].isna())
df_transaction[filt].isna().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order                 2
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
filt = (df_transaction['online_order'].isna())
df_transaction[filt].isna().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                        2
# product_line                 2
# product_class                2
# product_size                 2
# list_price                   0
# standard_cost                2
# product_first_sold_date      2
# dtype: int64

# %%
df_transaction['transaction_date'].min()
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
df_transaction['transaction_date'].max()
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
df_transaction['product_line'].value_counts()
# Out:
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64

# %%
df_transaction['order_status'].value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
df_customer_list.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value'],
#       dtype='object')

# %%
df_transaction.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
df_cust_address.merge(df_transaction,how='inner', on='customer_id')
# Out:
#        customer_id                   address  postcode            state  \
# 0                1        060 Morning Avenue      2016  New South Wales
# 1                1        060 Morning Avenue      2016  New South Wales
# 2                1        060 Morning Avenue      2016  New South Wales
# 3                1        060 Morning Avenue      2016  New South Wales
# 4                1        060 Morning Avenue      2016  New South Wales
# ...            ...                       ...       ...              ...
# 19963         3500  9491 Green Ridge Terrace      2100              NSW
# 19964         3500  9491 Green Ridge Terrace      2100              NSW
# 19965         3500  9491 Green Ridge Terrace      2100              NSW
# 19966         3500  9491 Green Ridge Terrace      2100              NSW
# 19967         3500  9491 Green Ridge Terrace      2100              NSW
#
#          country  property_valuation  transaction_id  product_id  \
# ...

# %% [markdown]
# ## Part II

# %%
df_transaction.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
print(df_transaction.shape)
print(df_cust_address.shape)
print(df_cust_demo.shape)
# Out:
# (20000, 13)
# (3999, 6)
# (4000, 13)

# %%
df_transaction.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
df_cust_address.columns
# Out:
# Index(['customer_id', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object')

# %%
df_cust_demo.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
df_merge = df_cust_demo.merge(df_cust_address, how = 'inner', on = 'customer_id')

# %%
df_merge
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               4          Talbot        NaN    Male
# 3               5  Sheila-kathryn     Calton  Female
# 4               6            Curr  Duckhouse    Male
# ...           ...             ...        ...     ...
# 3991         3996         Rosalia   Halgarth  Female
# 3992         3997          Blanch     Nisuis  Female
# 3993         3998          Sarene    Woolley       U
# 3994         3999       Patrizius        NaN    Male
# 3995         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      33 1961-10-03                     NaN
# ...

# %%
df_merge.isna().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              504
# job_industry_category                  655
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# dtype: int64

# %%
df_merge.drop(columns=['default'], inplace = True)

# %%
df_merge.gender.value_counts()
# Out:
# Female    2035
# Male      1870
# U           88
# Femal        1
# M            1
# F            1
# Name: gender, dtype: int64

# %% [markdown]
# ## Update Gender columns

# %%
df_merge['gender'].replace({'F':'Female', 'M':'Male', 'Femal':'Female', 'U': 'Unknown'}, inplace=True)

# %%
df_merge['gender'].value_counts()
# Out:
# Female     2037
# Male       1871
# Unknown      88
# Name: gender, dtype: int64

# %% [markdown]
# ## Update DOB

# %%
filt = df_merge['DOB']=='1843-12-21'
df_merge[filt]
# Out:
#     customer_id first_name last_name   gender  \
# 29           34   Jephthah  Bachmann  Unknown
#
#     past_3_years_bike_related_purchases        DOB        job_title  \
# 29                                   59 1843-12-21  Legal Assistant
#
#    job_industry_category     wealth_segment deceased_indicator owns_car  \
# 29                    IT  Affluent Customer                  N       No
#
#     tenure         address  postcode state    country  property_valuation
# 29    20.0  833 Luster Way      4005   QLD  Australia                   8

# %%
df_merge.drop(index=29, inplace=True)

# %% [markdown]
# ## Update Job title and Job Contegory

# %%
df_merge['job_title'].fillna('Unknown', inplace=True)

# %%
df_merge['job_industry_category'].fillna('Unknown', inplace=True)

# %%
filt = ((df_merge['job_title']=='Unknown') & (df_merge['job_industry_category']=='Unknown'))

# %%
df_merge[filt]
# Out:
#       customer_id first_name  last_name  gender  \
# 41             46      Kaila      Allin  Female
# 69             74      Pansy     Kiddie  Female
# 103           108      Kayle    Mingaud  Female
# 156           161       Tadd      Bloss    Male
# 173           178   Matthieu  Bertelmot    Male
# ...           ...        ...        ...     ...
# 3835         3840       Marc    Torrans    Male
# 3888         3893     Hadria      Moles  Female
# 3924         3929     Jacqui    Fortnam  Female
# 3928         3933    Chiarra       Cops  Female
# 3954         3959     Dannie     Sowray    Male
#
#       past_3_years_bike_related_purchases        DOB job_title  \
# 41                                     98 1972-02-26   Unknown
# 69                                     94 1969-06-19   Unknown
# 103                                     4 1994-03-14   Unknown
# 156                                    49 1976-01-21   Unknown
# 173                                     2 1967-04-03   Unknown
# ...

# %%
filt = df_merge[(df_merge['job_title']=='Unknown') & (df_merge['job_industry_category']=='Unknown')]

# %%
df_merge.drop(filt.index, inplace=True)

# %%
df_merge
# Out:
#       customer_id      first_name  last_name   gender  \
# 0               1         Laraine  Medendorp   Female
# 1               2             Eli    Bockman     Male
# 2               4          Talbot        NaN     Male
# 3               5  Sheila-kathryn     Calton   Female
# 4               6            Curr  Duckhouse     Male
# ...           ...             ...        ...      ...
# 3991         3996         Rosalia   Halgarth   Female
# 3992         3997          Blanch     Nisuis   Female
# 3993         3998          Sarene    Woolley  Unknown
# 3994         3999       Patrizius        NaN     Male
# 3995         4000           Kippy    Oldland     Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      33 1961-10-03                 Unknown
# ...

# %% [markdown]
# ## Deceased Column
#
# Only two values has Y, can drop the column

# %%
df_merge['deceased_indicator'].value_counts()
# Out:
# N    3889
# Y       2
# Name: deceased_indicator, dtype: int64

# %%
df_merge.drop(columns=['deceased_indicator'], inplace = True)

# %% [markdown]
# ## Tenure Column
#
# drop the na values

# %%
df_merge.dropna(subset=['tenure'], inplace=True)

# %%
df_merge
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp  Female
# 1               2             Eli    Bockman    Male
# 2               4          Talbot        NaN    Male
# 3               5  Sheila-kathryn     Calton  Female
# 4               6            Curr  Duckhouse    Male
# ...           ...             ...        ...     ...
# 3990         3995           Rusty     Iapico    Male
# 3991         3996         Rosalia   Halgarth  Female
# 3992         3997          Blanch     Nisuis  Female
# 3994         3999       Patrizius        NaN    Male
# 3995         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      33 1961-10-03                 Unknown
# ...

# %%
df_merge.isna().sum()
# Out:
# customer_id                            0
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# owns_car                               0
# tenure                                 0
# address                                0
# postcode                               0
# state                                  0
# country                                0
# property_valuation                     0
# dtype: int64

# %%
df_merge['last_name'].fillna('Unknown', inplace=True)

# %%
df_merge['state'].value_counts()
# Out:
# NSW                1955
# VIC                 899
# QLD                 791
# New South Wales      84
# Victoria             75
# Name: state, dtype: int64

# %%
df_merge['state'].replace({'New South Wales': 'NSW', 'Victoria':'VIC'}, inplace=True)

# %%
df_merge['state'].value_counts()
# Out:
# NSW    2039
# VIC     974
# QLD     791
# Name: state, dtype: int64

# %%
df_merge['country'].value_counts()
# Out:
# Australia    3804
# Name: country, dtype: int64

# %% [markdown]
# ### Analysis for transaction dataset

# %%
df_merge.isna().sum()
# Out:
# customer_id                            0
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# owns_car                               0
# tenure                                 0
# address                                0
# postcode                               0
# state                                  0
# country                                0
# property_valuation                     0
# dtype: int64

# %%
df_transaction.isna().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
df_transaction['brand'].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
filt = df_transaction['brand'].isna()

# %%
df_transaction = df_transaction[-filt]

# %%
df_transaction.isna().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               358
# order_status                 0
# brand                        0
# product_line                 0
# product_class                0
# product_size                 0
# list_price                   0
# standard_cost                0
# product_first_sold_date      0
# dtype: int64

# %%
filt = df_transaction['online_order'].isna()

# %%
df_transaction[filt]
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 97                 98          49          333       2017-06-23           NaN
# 166               167          90         3177       2017-04-26           NaN
# 169               170           6          404       2017-10-16           NaN
# 250               251          63         1967       2017-04-11           NaN
# 300               301          78         2530       2017-03-24           NaN
# ...               ...         ...          ...              ...           ...
# 19514           19515          51          690       2017-01-22           NaN
# 19573           19574          18         1735       2017-01-15           NaN
# 19580           19581          49         1933       2017-10-12           NaN
# 19635           19636          98         1389       2017-07-26           NaN
# 19843           19844           3            8       2017-01-28           NaN
#
# ...

# %%
df_transaction['online_order'].value_counts()
# Out:
# 1.0    9739
# 0.0    9706
# Name: online_order, dtype: int64

# %%
df_transaction.shape
# Out:
# (19803, 13)

# %% [markdown]
# ### Merge transaction and other table in one

# %%
filt = df_transaction['customer_id']==8

# %%
df_transaction[filt]
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 3687             3688          15            8       2017-09-22           1.0
# 5320             5321           3            8       2017-12-08           1.0
# 7635             7636          34            8       2017-07-13           1.0
# 8414             8415          76            8       2017-04-11           0.0
# 9038             9039           4            8       2017-10-21           1.0
# 10791           10792          89            8       2017-01-04           1.0
# 13265           13266           4            8       2017-10-04           0.0
# 15023           15024           1            8       2017-04-21           0.0
# 17198           17199          45            8       2017-08-11           0.0
# 19843           19844           3            8       2017-01-28           NaN
#
#       order_status           brand product_line product_class product_size  \
# ...

# %%
df_transaction['Profit'] = df_transaction['list_price'] - df_transaction['standard_cost']
# Out:
# /Users/narendransingh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_transaction
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
df_dummy = df_transaction.merge(df_merge, how='inner', on='customer_id')

# %%
df_dummy.isna().sum()
# Out:
# transaction_id                           0
# product_id                               0
# customer_id                              0
# transaction_date                         0
# online_order                           339
# order_status                             0
# brand                                    0
# product_line                             0
# product_class                            0
# product_size                             0
# list_price                               0
# standard_cost                            0
# product_first_sold_date                  0
# Profit                                   0
# first_name                               0
# last_name                                0
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                      0
# job_title                                0
# job_industry_category                    0
# wealth_segment                           0
# ...

# %%
filt = df_dummy['first_name'].isna()

# %%
df_dummy
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1               11065           1         2950       2017-10-16           0.0
# 2               18923          62         2950       2017-04-26           0.0
# 3                   2           3         3120       2017-05-21           1.0
# 4                6862           4         3120       2017-10-05           0.0
# ...               ...         ...          ...              ...           ...
# 18843           18735          45         3168       2017-02-21           1.0
# 18844           18789          83         3168       2017-04-11           0.0
# 18845           19113           3         3168       2017-06-03           0.0
# 18846           19912           3         3168       2017-09-30           0.0
# 18847           18822          30         3464       2017-12-13           NaN
#
# ...

# %%
filt = df_merge['customer_id']==3473

# %%
df_merge[filt]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, owns_car, tenure, address, postcode, state, country, property_valuation]
# Index: []

# %%
df_dummy['transaction_date'].max()
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
df_dummy['DOB'].max()
# Out:
# Timestamp('2002-03-11 00:00:00')

# %%
now = pd.Timestamp('2017-12-31 00:00:00')

# %%
df_dummy['age'] = (now - df_dummy['DOB']).astype('<m8[Y]')

# %%
df_dummy['age'].dtype
# Out:
# dtype('<m8[ns]')

# %%
df_dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18848 entries, 0 to 18847
# Data columns (total 30 columns):
# transaction_id                         18848 non-null int64
# product_id                             18848 non-null int64
# customer_id                            18848 non-null int64
# transaction_date                       18848 non-null datetime64[ns]
# online_order                           18509 non-null float64
# order_status                           18848 non-null object
# brand                                  18848 non-null object
# product_line                           18848 non-null object
# product_class                          18848 non-null object
# product_size                           18848 non-null object
# list_price                             18848 non-null float64
# standard_cost                          18848 non-null float64
# product_first_sold_date                18848 non-null object
# ...

# %%
df_dummy.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved  Giant Bicycles     Standard        medium       medium
# 2     Approved           Solex     Standard        medium       medium
# 3     Approved   Trek Bicycles     Standard        medium        large
# 4     Approved  Giant Bicycles     Standard          high       medium
#
#    list_price  standard_cost product_first_sold_date   Profit first_name  \
# ...

# %%
df_dummy.shape
# Out:
# (18848, 30)

# %%
df_final = df_dummy.dropna()

# %%
df_final.shape
# Out:
# (18509, 30)

# %%
df_final.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved  Giant Bicycles     Standard        medium       medium
# 2     Approved           Solex     Standard        medium       medium
# 3     Approved   Trek Bicycles     Standard        medium        large
# 4     Approved  Giant Bicycles     Standard          high       medium
#
#    list_price  standard_cost product_first_sold_date   Profit first_name  \
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18509 entries, 0 to 18846
# Data columns (total 30 columns):
# transaction_id                         18509 non-null int64
# product_id                             18509 non-null int64
# customer_id                            18509 non-null int64
# transaction_date                       18509 non-null datetime64[ns]
# online_order                           18509 non-null float64
# order_status                           18509 non-null object
# brand                                  18509 non-null object
# product_line                           18509 non-null object
# product_class                          18509 non-null object
# product_size                           18509 non-null object
# list_price                             18509 non-null float64
# standard_cost                          18509 non-null float64
# product_first_sold_date                18509 non-null object
# ...

# %%
df_final.to_excel('clean_data.xlsx')

# %% [markdown]
# ## Finding Coorelation

# %%
corr = df_final.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(30, 30))

sns.heatmap(corr[(corr >= 0.4) | (corr <= -0.4)], annot=True)

# %% [markdown]
# ## Exploring New Customers

# %%
df_customer_list = pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name =2, header=1)

# %%
df_customer_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
# first_name                             1000 non-null object
# last_name                              971 non-null object
# gender                                 1000 non-null object
# past_3_years_bike_related_purchases    1000 non-null int64
# DOB                                    983 non-null datetime64[ns]
# job_title                              894 non-null object
# job_industry_category                  835 non-null object
# wealth_segment                         1000 non-null object
# deceased_indicator                     1000 non-null object
# owns_car                               1000 non-null object
# tenure                                 1000 non-null int64
# address                                1000 non-null object
# postcode                               1000 non-null int64
# state                                  1000 non-null object
# ...

# %%
df_customer_list.isna().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
df_customer_list['last_name'].fillna('Unknown', inplace=True)

# %%
df_customer_list['job_title'].fillna('Unknown', inplace=True)

# %%
df_customer_list['job_industry_category'].fillna('Unknown', inplace=True)

# %%
df_customer_list = df_customer_list.dropna()

# %%
df_customer_list['deceased_indicator'].value_counts()
# Out:
# N    983
# Name: deceased_indicator, dtype: int64

# %%
df_customer_list.drop(columns='deceased_indicator', inplace=True)

# %%
df_customer_list.shape
# Out:
# (983, 22)

# %%
df_customer_list['DOB'].max()
# Out:
# Timestamp('2002-02-27 00:00:00')

# %%
now = pd.Timestamp('2017-12-31 00:00:00')
df_customer_list['age'] = (now - df_customer_list['DOB']).astype('<m8[Y]')

# %%
df_customer_list.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment owns_car  tenure              address  postcode state  \
# 0      Mass Customer      Yes      14     45 Shopko Center      4500   QLD
# ...

# %%
df_customer_list.to_excel('clean_new_customer_list_data.xlsx')

# %%
df_final.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved  Giant Bicycles     Standard        medium       medium
# 2     Approved           Solex     Standard        medium       medium
# 3     Approved   Trek Bicycles     Standard        medium        large
# 4     Approved  Giant Bicycles     Standard          high       medium
#
#    list_price  standard_cost product_first_sold_date   Profit first_name  \
# ...

# %%
plt.figure(figsize=(5,5))
plt.hist(df_final['age'], bins=20)
plt.title('Age distribution for Previos Customers')
plt.xlabel('Age')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.hist(df_customer_list['age'], bins=20)
plt.title('Age Distribution for New Customers')
plt.xlabel('Age')
plt.show()

# %%
plt.bar(df_final['gender'], df_final['Profit'])
# Out:
# <BarContainer object of 18509 artists>
